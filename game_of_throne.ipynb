# %% [markdown]
# <a href="https://colab.research.google.com/github/trapti-singh/portfolio1/blob/main/game_of_throne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
    import os
    os.makedirs('/content/drive/MyDrive/your_folder_name', exist_ok=True)

# %%
import numpy as np

# %%
import pandas as pd

# %%
# !pip install gensim

# %%
import gensim

# %%
import os

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from google.colab import files
uploaded = files.upload()

df = pd.read_csv('001ssb.txt')
# Out:
#      <input type="file" id="files-4b98367d-3103-4d22-9ed5-8d40e23d21e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b98367d-3103-4d22-9ed5-8d40e23d21e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("001ssb.txt", "r", encoding="windows-1252") as f:
    data = f.read()

# %%
len(data)
# Out:
# 1607894

# %%
len(data.split(" "))
# Out:
# 295613

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
import nltk # Import nltk here
story = []
for filename in os.listdir('data'):
  f=open(os.path.join('data', filename))
  print(os.path.join('data', filename))
  corpus = f.read()
  raw_sent = sent_tokenize(corpus)
  for sent in raw_sent:
    story.append(simple_preprocess(sent))
# Out:
# data/001ssb.txt
# data/005ssb.txt
# data/002ssb.txt
# data/004ssb.txt
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-38-2554512930> in <cell line: 0>()
#       6   f=open(os.path.join('data', filename))
#       7   print(os.path.join('data', filename))
# ----> 8   corpus = f.read()
#       9   raw_sent = sent_tokenize(corpus)
#      10   for sent in raw_sent:
#
# /usr/lib/python3.11/codecs.py in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x93 in position 151: invalid start byte

# %%
len(story)
# Out:
# 27244

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2,
    workers=4,
)

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (1059314, 1423500)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('tired', 0.9965887665748596),
#  ('samwell', 0.9964377880096436),
#  ('noye', 0.9956897497177124),
#  ('supper', 0.9956589937210083),
#  ('wandering', 0.9951305985450745),
#  ('making', 0.9950995445251465),
#  ('ugly', 0.9950398802757263),
#  ('mycah', 0.9949563145637512),
#  ('arrived', 0.9948953986167908),
#  ('tarly', 0.9947841167449951)]

# %%
model.wv.doesnt_match(['jon','rikon','robb','arya','sansa','bran'])
# Out:
# WARNING:gensim.models.keyedvectors:vectors for words {'rikon'} are not present in the model, ignoring these words
# 'robb'

# %%
model.wv.doesnt_match(['cersei', 'jaime','bronn','tyrion'])
# Out:
# 'jaime'

# %%
model.wv['king'].shape
# Out:
# (100,)

# %%
model.wv.similarity('cersei','sansa')
# Out:
# 0.88715726

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.08218099, -0.010602  ,  0.05491916, ..., -0.16256414,
#         -0.03534899,  0.13791981],
#        [-0.05000918,  0.07348294,  0.02949574, ..., -0.18725821,
#          0.05512853,  0.03862309],
#        [-0.17815445,  0.05630592, -0.00840287, ..., -0.06188654,
#          0.0516563 , -0.13009907],
#        ...,
#        [-0.05475039, -0.11413177,  0.01757134, ..., -0.17602155,
#          0.05127392, -0.05085439],
#        [ 0.00066216,  0.03525857,  0.01664533, ..., -0.18319358,
#          0.01932248, -0.00644479],
#        [-0.04114832,  0.10730235,  0.00617485, ..., -0.17404237,
#          0.01107367, -0.01991839]], dtype=float32)

# %%
y=model.wv.index_to_key

# %%
len(y)
# Out:
# 7432

# %%
from tkinter.constants import X
from sklearn.decomposition import PCA
pca=PCA(n_components=3)
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X[:5]
# Out:
# array([[ 0.3831281 , -0.17423677,  0.35960147],
#        [ 0.47366413, -0.06562895,  0.23282224],
#        [-0.4197372 , -0.1426019 ,  0.03453052],
#        [ 0.31644353, -0.06340861,  0.54502547],
#        [-0.19330625, -0.38113257, -0.4029858 ]], dtype=float32)

# %%
import plotly.express as px
fig = px.scatter_3d(X[:500], x=0, y=1, z=2, color=y[:500])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip uninstall numpy -y
# !pip install numpy==1.23.5

# %% [markdown]
# **Please restart the runtime after executing the above cell.**
